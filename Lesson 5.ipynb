# %% [markdown]
# <a href="https://colab.research.google.com/github/DimaSokolov73/Homeworks/blob/main/Lesson%205.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
N = int
print [N]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-a62ca28c20b3> in <cell line: 0>()
# ----> 1 N = int (input(N=[]))
#       2 print [N]
#
# TypeError: Kernel.raw_input() got an unexpected keyword argument 'N'

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
N = [3,5,7,9,10]
K = int (input("K="))
L = int (input("L="))
sum (N)
# Out:
# K=5
# L=6

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
A = [1,3,5,7,9]
B = [0,2,4,6,8]
print
# Out:
# 9
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-93908d510914> in <cell line: 0>()
#       1 A = [1,3,5,7,9]
#       2 B = [0,2,4,6,8]
# ----> 3 print (max (A)) + (max(B))
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'int'

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
N = [15,3,5,1,9]
min_index = N.index (min(N))
max_index = N.index (max(N))
N[min_index], N[max_index] = N[max_index],N[min_index]
print (N)
# Out:
# [1, 3, 5, 15, 9]
