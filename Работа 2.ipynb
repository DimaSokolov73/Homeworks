# %% [markdown]
# <a href="https://colab.research.google.com/github/DimaSokolov73/Homeworks/blob/main/%D0%A0%D0%B0%D0%B1%D0%BE%D1%82%D0%B0%202.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1

# %%
c= float (input ('c='))
y= float (input ('y='))
a=((c*y-2*c+2*(y+c))/(7*(c+2)))
print (a)
# Out:
# c=10
# y=5
# 0.7142857142857143

# %% [markdown]
# 2

# %%
import math
x= float (input ('x='))
z=math.sin(x)/(math.log(7*x))+3*math.log(5*x)
print (z)
# Out:
# x=234
# 21.329229857517916

# %% [markdown]
# 3

# %%
x= float (input ('x='))
y= float (input ('y='))
v= x+y
f= x-y
l= x*y
p= x/y
print (v,f,l,p)
# Out:
# x=1
# y=2
# 3.0 -1.0 2.0 0.5

# %% [markdown]
# 4

# %%
s=int(input("s:"))
K=(s+3)%7
print(K)
# Out:
# s:25
# 0

# %% [markdown]
# 5

# %%
A= int (input ('A='))
B= int (input ('B='))
C= int (input ('C='))
Z= A>0 or B>0 or C>0
print (Z)
# Out:
# A=-2
# B=-2
# C=5
# True
